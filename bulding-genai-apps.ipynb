# %%
import os
import time
import pprint
import pymongo
from dotenv import load_dotenv
from pymongo.operations import SearchIndexModel
from openai import OpenAI
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_transformers.openai_functions import create_metadata_tagger
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.prompts import PromptTemplate

# %%
load_dotenv(".env")
# Out:
# True

# %% [markdown]
# ### Text embeddings

# %%
openai = OpenAI()

# %%
EMBEDDING_MODEL = "text-embedding-ada-002"

# %%
vector = openai.embeddings.create(
    model=EMBEDDING_MODEL,
    input="The food was delicious and the waiter..."
)

# %%
len(vector.data[0].embedding)
# Out:
# 1536

# %%
def get_embedding(query_str):
    vector = openai.embeddings.create(model=EMBEDDING_MODEL, input=query_str)
    return vector.data[0].embedding

# %%
MONGODB_URI = os.getenv("MONGODB_URI")

# %% [markdown]
# ### Creating a vector search index

# %%
client = pymongo.MongoClient(MONGODB_URI)

# %%
db = client.sample_mflix

# %%
embedded_movies_collection = db.embedded_movies

# %%
vector_search_index_model = SearchIndexModel(
    name="plot_embedding_idx",
    type="vectorSearch",
    definition={
        "fields": [
            {
                "type": "vector",
                "path": "plot_embedding",
                "numDimensions": 1536,
                "similarity": "dotProduct",
                "quantization": "scalar"
            }
        ]
    }
)

# %%
result = embedded_movies_collection.create_search_index(model=vector_search_index_model)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 result = embedded_movies_collection.create_search_index(model=vector_search_index_model)
#
# File ~/miniconda3/envs/mongodb/lib/python3.13/site-packages/pymongo/synchronous/collection.py:2692, in Collection.create_search_index(self, model, session, comment, **kwargs)
#    2690 if not isinstance(model, SearchIndexModel):
#    2691     model = SearchIndexModel(**model)
# -> 2692 return (self._create_search_indexes([model], session, comment, **kwargs))[0]
#
# File ~/miniconda3/envs/mongodb/lib/python3.13/site-packages/pymongo/synchronous/collection.py:2740, in Collection._create_search_indexes(self, models, session, comment, **kwargs)
#    2737 cmd.update(kwargs)
#    2739 with self._conn_for_writes(session, operation=_Op.CREATE_SEARCH_INDEXES) as conn:
# -> 2740     resp = self._command(
#    2741         conn,
#    2742         cmd,
#    2743         read_preference=ReadPreference.PRIMARY,
#    2744         codec_options=_UNICODE_REPLACE_CODEC_OPTIONS,
#    2745     )
#    2746     return [index["name"] for index in resp["indexesCreated"]]
#
# File ~/miniconda3/envs/mongodb/lib/python3.13/site-packages/pymongo/synchronous/collection.py:621, in Collection._command(self, conn, command, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     595 """Internal command helper.
#     596
#     597 :param conn` - A Connection instance.
#    (...)    618 :return: The result document.
#     619 """
#     620 with self._database.client._tmp_session(session) as s:
# --> 621     return conn.command(
#     622         self._database.name,
#     623         command,
#     624         read_preference or self._read_preference_for(session),
#     625         codec_options or self.codec_options,
#     626         check,
#     627         allowable_errors,
#     628         read_concern=read_concern,
#     629         write_concern=write_concern,
#     630         parse_write_concern_error=True,
#     631         collation=collation,
#     632         session=s,
#     633         client=self._database.client,
#     634         retryable_write=retryable_write,
#     635         user_fields=user_fields,
#     636     )
#
# File ~/miniconda3/envs/mongodb/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File ~/miniconda3/envs/mongodb/lib/python3.13/site-packages/pymongo/synchronous/pool.py:536, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     534     self._raise_if_not_writable(unacknowledged)
#     535 try:
# --> 536     return command(
#     537         self,
#     538         dbname,
#     539         spec,
#     540         self.is_mongos,
#     541         read_preference,
#     542         codec_options,
#     543         session,
#     544         client,
#     545         check,
#     546         allowable_errors,
#     547         self.address,
#     548         listeners,
#     549         self.max_bson_size,
#     550         read_concern,
#     551         parse_write_concern_error=parse_write_concern_error,
#     552         collation=collation,
#     553         compression_ctx=self.compression_context,
#     554         use_op_msg=self.op_msg_enabled,
#     555         unacknowledged=unacknowledged,
#     556         user_fields=user_fields,
#     557         exhaust_allowed=exhaust_allowed,
#     558         write_concern=write_concern,
#     559     )
#     560 except (OperationFailure, NotPrimaryError):
#     561     raise
#
# File ~/miniconda3/envs/mongodb/lib/python3.13/site-packages/pymongo/synchronous/network.py:213, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     211             client._process_response(response_doc, session)
#     212         if check:
# --> 213             helpers_shared._check_command_response(
#     214                 response_doc,
#     215                 conn.max_wire_version,
#     216                 allowable_errors,
#     217                 parse_write_concern_error=parse_write_concern_error,
#     218             )
#     219 except Exception as exc:
#     220     duration = datetime.datetime.now() - start
#
# File ~/miniconda3/envs/mongodb/lib/python3.13/site-packages/pymongo/helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: An index named "plot_embedding_idx" is already defined for collection embedded_movies. Index names must be unique for a source collection and all its views., full error: {'ok': 0.0, 'errmsg': 'An index named "plot_embedding_idx" is already defined for collection embedded_movies. Index names must be unique for a source collection and all its views.', 'code': 68, 'codeName': 'IndexAlreadyExists', '$clusterTime': {'clusterTime': Timestamp(1740934367, 9), 'signature': {'hash': b'\x96I\x87~\xe8\xaf\x1av\x17"\xd7\x88\xfb\xc3\xac\x8c\xe75\x10\xfc', 'keyId': 7431213296700620803}}, 'operationTime': Timestamp(1740934367, 9)}

# %%
print("New search index named " + result + " is building.")

# %%
print("Polling to check if the index is ready. This may take up to a minute.")
predicate = None
if predicate is None:
    predicate = lambda index: index.get("queryable") is True

while True:
    indices = list(embedded_movies_collection.list_search_indexes(result))
    if len(indices) and predicate(indices[0]):
        break
    time.sleep(5)
print(result + " is ready for querying.")

# %% [markdown]
# ### Editing a vector search index

# %%
new_definition = {
    "fields": [
        {
            "type": "vector",
            "path": "plot_embedding",
            "numDimensions": 1536,
            "similarity": "dotProduct",
            "quantization": "scalar"
        },
        {
            "type": "filter",
            "path": "genres"
        },
        {
            "type": "filter",
            "path": "year"
        }
    ]
}

# %%
embedded_movies_collection.update_search_index("plot_embedding_idx", new_definition)

# %% [markdown]
# ### Creating a vector query for semantic search

# %%
query = "A movie about people who are trying to escape from a maximum security facility."

embedding = get_embedding(query)

# %%
vector_search = {
    "$vectorSearch": {
        "index": "plot_embedding_idx",
        "path": "plot_embedding",
        "queryVector": embedding,
        "numCandidates": 100, # good practice: 10*limit
        "limit": 10
    }
}

select_fields = {
    "$project": {
        "title": 1,
        "plot": 1,
        "score": {"$meta": "vectorSearchScore"}
    }
}

pipeline = [vector_search, select_fields]

# %%
cursor = embedded_movies_collection.aggregate(pipeline)

# %%
for doc in cursor:
    pprint.pprint(doc)
# Out:
# {'_id': ObjectId('573a13c1f29313caabd649a8'),
#  'plot': 'When a structural-security authority finds himself set up and '
#          "incarcerated in the world's most secret and secure prison, he has to "
#          'use his skills to escape with help from the inside.',
#  'score': 0.9361114501953125,
#  'title': 'Escape Plan'}
# {'_id': ObjectId('573a1399f29313caabcedb10'),
#  'plot': 'A futuristic prison movie. Protagonist and wife are nabbed at a '
#          'future US emigration point with an illegal baby during population '
#          'control. The resulting prison experience is the subject of ...',
#  'score': 0.9358062744140625,
#  'title': 'Fortress'}
# {'_id': ObjectId('573a13c2f29313caabd66751'),
#  'plot': 'The story of two men on different sides of a prison riot -- the '
#          'inmate leading the rebellion and the young guard trapped in the '
#          'revolt, who poses as a prisoner in a desperate attempt to survive '
#          'the ordeal.',
#  'score': 0.9333038330078125,
#  'title': 'Cell 211'}
# {'_id': ObjectId('573a13a7f29313caabd1a68a'),
#  'plot': 'This movie tells the story of a man who goes undercover in a hi-tech '
#          'prison to find out information to help prosecute those who killed '
#          'his wife. While there he stumbles onto a plot involving a death-row '
#          'inmate and his $200 million stash of gold.',
#  'score': 0.93255615234375,
#  'title': 'Half Past Dead'}
# {'_id': ObjectId('573a139af29313caabcf0823'),
#  'plot': 'A newly released ex-con and former US Ranger finds himself trapped '
#          'in a prisoner transport plane when the passengers seize control.',
#  'score': 0.9314422607421875,
#  'title': 'Con Air'}
# {'_id': ObjectId('573a1396f29313caabce4a94'),
#  'plot': 'A recently released ex-con and his loyal wife go on the run after a '
#          'heist goes awry.',
#  'score': 0.930999755859375,
#  'title': 'The Getaway'}
# {'_id': ObjectId('573a1397f29313caabce7e2a'),
#  'plot': 'In 1997, when the US President crashes into Manhattan, now a giant '
#          'maximum security prison, a convicted bank robber is sent in for a '
#          'rescue.',
#  'score': 0.929656982421875,
#  'title': 'Escape from New York'}
# {'_id': ObjectId('573a13c5f29313caabd70568'),
#  'plot': 'A woman rebels against a tyrannical ruler in post apocalyptic '
#          'Australia in search for her homeland with the help of a group of '
#          'female prisoners, a psychotic worshiper, and a drifter named Max.',
#  'score': 0.9282989501953125,
#  'title': 'Mad Max: Fury Road'}
# {'_id': ObjectId('573a13b5f29313caabd4473e'),
#  'plot': 'A film set in a strange afterlife way station that has been reserved '
#          'for people who have committed suicide.',
#  'score': 0.927459716796875,
#  'title': 'Wristcutters: A Love Story'}
# {'_id': ObjectId('573a13bcf29313caabd5773c'),
#  'plot': 'A young girl is institutionalized by her abusive stepfather. '
#          'Retreating to an alternative reality as a coping strategy, she '
#          'envisions a plan which will help her escape from the mental '
#          'facility.',
#  'score': 0.9266815185546875,
#  'title': 'Sucker Punch'}

# %%
vector_search_with_filter = {
    "$vectorSearch": {
        "index": "plot_embedding_idx",
        "path": "plot_embedding",
        "queryVector": embedding,
        "numCandidates": 100, # good practice: 10*limit
        "limit": 10,
        "filter": {"year": {"$gte": 2000}}
    }
}

select_fields = {
    "$project": {
        "title": 1,
        "plot": 1,
        "year": 1,
        "score": {"$meta": "vectorSearchScore"}
    }
}

pipeline = [vector_search, select_fields]

# %%
cursor = embedded_movies_collection.aggregate(pipeline)

# %%
for doc in cursor:
    pprint.pprint(doc)
# Out:
# {'_id': ObjectId('573a13c1f29313caabd649a8'),
#  'plot': 'When a structural-security authority finds himself set up and '
#          "incarcerated in the world's most secret and secure prison, he has to "
#          'use his skills to escape with help from the inside.',
#  'score': 0.9361114501953125,
#  'title': 'Escape Plan',
#  'year': 2013}
# {'_id': ObjectId('573a1399f29313caabcedb10'),
#  'plot': 'A futuristic prison movie. Protagonist and wife are nabbed at a '
#          'future US emigration point with an illegal baby during population '
#          'control. The resulting prison experience is the subject of ...',
#  'score': 0.9358062744140625,
#  'title': 'Fortress',
#  'year': 1992}
# {'_id': ObjectId('573a13c2f29313caabd66751'),
#  'plot': 'The story of two men on different sides of a prison riot -- the '
#          'inmate leading the rebellion and the young guard trapped in the '
#          'revolt, who poses as a prisoner in a desperate attempt to survive '
#          'the ordeal.',
#  'score': 0.9333038330078125,
#  'title': 'Cell 211',
#  'year': 2009}
# {'_id': ObjectId('573a13a7f29313caabd1a68a'),
#  'plot': 'This movie tells the story of a man who goes undercover in a hi-tech '
#          'prison to find out information to help prosecute those who killed '
#          'his wife. While there he stumbles onto a plot involving a death-row '
#          'inmate and his $200 million stash of gold.',
#  'score': 0.93255615234375,
#  'title': 'Half Past Dead',
#  'year': 2002}
# {'_id': ObjectId('573a139af29313caabcf0823'),
#  'plot': 'A newly released ex-con and former US Ranger finds himself trapped '
#          'in a prisoner transport plane when the passengers seize control.',
#  'score': 0.9314422607421875,
#  'title': 'Con Air',
#  'year': 1997}
# {'_id': ObjectId('573a1396f29313caabce4a94'),
#  'plot': 'A recently released ex-con and his loyal wife go on the run after a '
#          'heist goes awry.',
#  'score': 0.930999755859375,
#  'title': 'The Getaway',
#  'year': 1972}
# {'_id': ObjectId('573a1397f29313caabce7e2a'),
#  'plot': 'In 1997, when the US President crashes into Manhattan, now a giant '
#          'maximum security prison, a convicted bank robber is sent in for a '
#          'rescue.',
#  'score': 0.929656982421875,
#  'title': 'Escape from New York',
#  'year': 1981}
# {'_id': ObjectId('573a13c5f29313caabd70568'),
#  'plot': 'A woman rebels against a tyrannical ruler in post apocalyptic '
#          'Australia in search for her homeland with the help of a group of '
#          'female prisoners, a psychotic worshiper, and a drifter named Max.',
#  'score': 0.9282989501953125,
#  'title': 'Mad Max: Fury Road',
#  'year': 2015}
# {'_id': ObjectId('573a13b5f29313caabd4473e'),
#  'plot': 'A film set in a strange afterlife way station that has been reserved '
#          'for people who have committed suicide.',
#  'score': 0.927459716796875,
#  'title': 'Wristcutters: A Love Story',
#  'year': 2006}
# {'_id': ObjectId('573a13bcf29313caabd5773c'),
#  'plot': 'A young girl is institutionalized by her abusive stepfather. '
#          'Retreating to an alternative reality as a coping strategy, she '
#          'envisions a plan which will help her escape from the mental '
#          'facility.',
#  'score': 0.9266815185546875,
#  'title': 'Sucker Punch',
#  'year': 2011}

# %% [markdown]
# ### Vector search for RAG applications

# %%
loader = PyPDFLoader("MongoDB-manual.pdf")
pages = loader.load()
# Out:
# Multiple definitions in dictionary at byte 0x7a2c4e for key /Author
# Multiple definitions in dictionary at byte 0x7a2c56 for key /Title

# %%
print(pages[0])
# Out:
# page_content='MongoDB Documentation
# Release 3.0.4
# MongoDB Documentation Project
# June 29, 2015' metadata={'producer': 'pdfTeX-1.40.15', 'creator': 'LaTeX with hyperref package', 'creationdate': '2015-06-29T10:51:25-04:00', 'author': 'MongoDB Documentation Project', 'title': 'MongoDB Documentation', 'subject': '', 'keywords': '', 'moddate': '2015-06-29T10:51:25-04:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) kpathsea version 6.2.0', 'source': 'MongoDB-manual.pdf', 'total_pages': 946, 'page': 0, 'page_label': '1'}

# %%
cleaned_pages = []
for page in pages:
    if len(page.page_content.split(" ")) > 20:
        cleaned_pages.append(page)

# %%
# Splitting the documents into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=150)

# %%
schema = {
    "properties": {
        "hasCode": {"type": "boolean"}
    },
    "required": ["hasCode"]
}

# %%
llm_model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
# Creating metadata for the documents
document_transformer = create_metadata_tagger(schema, llm_model)
docs = document_transformer.transform_documents(cleaned_pages)
split_docs = text_splitter.split_documents(docs)

# %%
# Generating vector embeddings for the documents
embeddings_model = OpenAIEmbeddings()

# %%
chunked_data_collection = client.langchain_demo.chunked_data

# %%
# Deleting the collection before adding new data
chunked_data_collection.delete_many({})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff000000000000001c'), 'opTime': {'ts': Timestamp(1740937366, 2), 't': 28}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1740937366, 2), 'signature': {'hash': b'J\x80\x1b\xbe\xb4\x9c)\xdb\x17Ls\xa50\xf9\xcb\x90.\xd6\x93\x07', 'keyId': 7431213296700620803}}, 'operationTime': Timestamp(1740937366, 2)}, acknowledged=True)

# %%
# Storing the vectors in MongoDB Atlas
vector_store = MongoDBAtlasVectorSearch.from_documents(split_docs,
                                                       embeddings_model,
                                                       collection=chunked_data_collection)

# %%
document_count = chunked_data_collection.count_documents({})
print(f"Successfully stored {document_count} documents in MongoDB Atlas")
# Out:
# Successfully stored 6059 documents in MongoDB Atlas

# %%
chunked_data_collection.find_one()
# Out:
# {'_id': ObjectId('67c4993b9be56e13b5cdc7d6'),
#  'text': 'Contents\n1 Introduction to MongoDB 3\n1.1 What is MongoDB . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 3\n2 Install MongoDB 5\n2.1 Recommended Operating Systems for Production Deployments . . . . . . . . . . . . . . . . . . . . 5\n2.2 Other Supported Operating Systems . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#   0.010696503333747387,
#   0.03263118863105774,
#   -0.0019823447801172733,
#   -0.01296763401478529,
#   0.028689341619610786,
#   0.0021797632798552513,
#   0.01061166264116764,
#   0.01980060525238514,
#   0.0006787287420593202,
#   0.006542553193867207,
#   0.0029841221403330564,
#   0.006336976774036884,
#   -0.014801506884396076,
#   -0.023076776415109634,
#   -0.0312737300992012,
#   -0.015832653269171715,
#   -0.012876266613602638,
#   0.0046368916518986225,
#   -0.002266236115247011,
#   -0.012177959084510803,
#   -0.008072955533862114,
#   -0.028219452127814293,
#   0.023533612489700317,
#   0.026131056249141693,
#   -0.009998195804655552,
#   0.03192635625600815,
#   0.011871226131916046,
#   0.011205550283193588,
#   -0.005472250282764435,
#   -0.010885764844715595,
#   -0.010768292471766472,
#   0.0010441980557516217,
#   -0.004287738353013992,
#   -0.015597707591950893,
#   0.031012682244181633,
#   -0.009671884588897228,
#   -0.004943625070154667,
#   0.01940903067588806,
#   -0.00019752066873479635,
#   0.013692046515643597,
#   0.005002361256629229,
#   -0.005211200565099716,
#   0.0021112379617989063,
#   -0.009887250140309334,
#   ...],
#  'hasCode': False,
#  'producer': 'pdfTeX-1.40.15',
#  'creator': 'LaTeX with hyperref package',
#  'creationdate': '2015-06-29T10:51:25-04:00',
#  'author': 'MongoDB Documentation Project',
#  'title': 'MongoDB Documentation',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2015-06-29T10:51:25-04:00',
#  'trapped': '/False',
#  'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) kpathsea version 6.2.0',
#  'source': 'MongoDB-manual.pdf',
#  'total_pages': 946,
#  'page': 2,
#  'page_label': 'i'}

# %%
vectorStore = MongoDBAtlasVectorSearch.from_connection_string(
    MONGODB_URI,
    "langchain_demo.chunked_data",
    OpenAIEmbeddings(disallowed_special=()),
    index_name="vector_index",
)

# %%
def query_data(query):
    retriever = vectorStore.as_retriever(
        search_type="similarity",
        search_kwargs={"k": 3},
    )

    template = """
    Use the following pieces of context to answer the question at the end.
    If you don't know the answer, just say that you don't know, don't try to make up an answer.
    Do not answer the question if there is no given context.
    Do not answer the question if it is not related to the context.
    Do not give recommendations to anything other than MongoDB.
    Context:
    {context}
    Question: {question}
    """

    custom_rag_prompt = PromptTemplate.from_template(template)

    retrieve = {
        "context": retriever
        | (lambda docs: "\n\n".join([d.page_content for d in docs])),
        "question": RunnablePassthrough(),
    }

    llm_model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

    response_parser = StrOutputParser()

    rag_chain = retrieve | custom_rag_prompt | llm_model | response_parser
    answer = rag_chain.invoke(query)
    print(answer)

# %%
# Test with a relevant query
question = "When did MongoDB begin supporting multi-document transactions?"
print(f"Running query: {question}")
query_data(question)

print("=========================================================")

# Test with an irrelevant query
question = "Why is the sky blue?"
print(f"Running query: {question}")
query_data(question)
# Out:
# Running query: When did MongoDB begin supporting multi-document transactions?
# MongoDB began supporting multi-document transactions in version 4.0, which was released in June 2018.
# =========================================================
# Running query: Why is the sky blue?
# I don't know.
